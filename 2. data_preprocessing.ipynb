# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("stock_data.csv")

# %%
# no need to normalize dividents, stock splits (since they are already normalized)
columns = ["Open", "High", "Low", "Close", "Volume", "Dividends", "Stock Splits"] 
data_subset = data[columns]

data_subset.head()
# Out:
#        Open      High       Low     Close      Volume  Dividends  Stock Splits
# 0  5.440290  5.474622  5.368389  5.392273   357340000      0.004           0.0
# 1  5.389279  5.402724  4.988681  5.282469  1527812000      0.000           0.0
# 2  5.259564  5.700994  5.250850  5.576756  1561116000      0.000           0.0
# 3  5.624311  5.985073  5.596177  5.959678  2034124000      0.000           0.0
# 4  5.988309  6.020427  5.871042  5.897434   931420000      0.000           0.0

# %%
# check for missing values
data.isnull().any()
# Out:
# Open            False
# High            False
# Low             False
# Close           False
# Volume          False
# Dividends       False
# Stock Splits    False
# Ticker          False
# dtype: bool

# %%
# normalize the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data_subset)

scaled_data
# Out:
# array([[2.19840681e-03, 4.87488773e-04, 6.39661269e-03, ...,
#         0.00000000e+00, 4.00000000e-01, 0.00000000e+00],
#        [1.84306979e-03, 0.00000000e+00, 3.59597001e-03, ...,
#         2.69540483e-01, 0.00000000e+00, 0.00000000e+00],
#        [9.39481816e-04, 2.02234733e-03, 5.52967274e-03, ...,
#         2.77209847e-01, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [1.00000000e+00, 9.78031966e-01, 1.00000000e+00, ...,
#         1.52014751e-01, 0.00000000e+00, 0.00000000e+00],
#        [9.36052567e-01, 1.00000000e+00, 9.78388902e-01, ...,
#         2.39399448e-01, 0.00000000e+00, 0.00000000e+00],
#        [9.53397838e-01, 9.26502159e-01, 9.39666051e-01, ...,
#         9.25333395e-02, 0.00000000e+00, 0.00000000e+00]])

# %%
# Convert numpy array to pandas DataFrame
df_scaled = pd.DataFrame(scaled_data, columns=columns)

# Save DataFrame to CSV file
df_scaled.to_csv('normalized_stock_data.csv', index=False)
